# %%
import pandas as pd
import tabula

# %%
dfs = tabula.read_pdf("../data/TEST.pdf", pages='all', multiple_tables=True)
# Out:
# Failed to import jpype dependencies. Fallback to subprocess.
# No module named 'jpype'

# %%
resultado = pd.concat(dfs, ignore_index=True)

# %%
resultado
# Out:
#        Sender  Receiver   Invoice    Acct  Sub  Type   Service      Bill  \
# 0         NaN       NaN  651411.0  192238  1.0   1.0  01/05/23  01/12/23
# 1         NaN       NaN  654225.0  192238  1.0   1.0  02/16/23  02/19/23
# 2         NaN       NaN  657868.0  192238  1.0   1.0  03/23/23  03/25/23
# 3         NaN       NaN  661551.0  192238  1.0   1.0  05/04/23  05/09/23
# 4         NaN       NaN  665316.0  192238  1.0   1.0  06/15/23  06/21/23
# ...       ...       ...       ...     ...  ...   ...       ...       ...
# 18289     NaN       NaN  683333.0  194971  1.0   1.0  12/25/23  12/30/23
# 18290     NaN       NaN       NaN     NaN  NaN   NaN       NaN       NaN
# 18291     NaN       NaN       NaN     NaN  NaN   NaN       NaN       NaN
# 18292     NaN       NaN       NaN     NaN  NaN   NaN       NaN       NaN
# 18293     NaN       NaN       NaN     NaN  NaN   NaN       NaN       NaN
#
#                            ID Name   Charge Unnamed: 0  Credit Payment  \
# ...

# %%
resultado.to_excel("resultado.xlsx")
